# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df= pd.read_csv(r"C:\Users\shivani\Downloads\archive.zip")

# %%
df
# Out:
#      Age  Gender  Cholesterol  Blood Pressure  Heart Rate  Smoking  \
# 0     75  Female          228             119          66  Current
# 1     48    Male          204             165          62  Current
# 2     53    Male          234              91          67    Never
# 3     69  Female          192              90          72  Current
# 4     62  Female          172             163          93    Never
# ..   ...     ...          ...             ...         ...      ...
# 995   56  Female          269             111          86    Never
# 996   78  Female          334             145          76    Never
# 997   79    Male          151             179          81    Never
# 998   60  Female          326             151          68   Former
# 999   53    Male          226             116          82  Current
#
#     Alcohol Intake  Exercise Hours Family History Diabetes Obesity  \
# 0            Heavy               1             No       No     Yes
# ...

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.duplicated().any().sum()
# Out:
# 0

# %% [markdown]
# # To check Statistical summary

# %%
df.describe()
# Out:
#                Age  Cholesterol  Blood Pressure   Heart Rate  Exercise Hours  \
# count  1000.000000  1000.000000       1000.0000  1000.000000     1000.000000
# mean     52.293000   249.939000        135.2810    79.204000        4.529000
# std      15.727126    57.914673         26.3883    11.486092        2.934241
# min      25.000000   150.000000         90.0000    60.000000        0.000000
# 25%      39.000000   200.000000        112.7500    70.000000        2.000000
# 50%      52.000000   248.000000        136.0000    79.000000        4.500000
# 75%      66.000000   299.000000        159.0000    89.000000        7.000000
# max      79.000000   349.000000        179.0000    99.000000        9.000000
#
#        Stress Level  Blood Sugar  Heart Disease
# count   1000.000000  1000.000000    1000.000000
# mean       5.646000   134.941000       0.392000
# std        2.831024    36.699624       0.488441
# min        1.000000    70.000000       0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1000 non-null   int64
#  1   Gender                   1000 non-null   object
#  2   Cholesterol              1000 non-null   int64
#  3   Blood Pressure           1000 non-null   int64
#  4   Heart Rate               1000 non-null   int64
#  5   Smoking                  1000 non-null   object
#  6   Alcohol Intake           660 non-null    object
#  7   Exercise Hours           1000 non-null   int64
#  8   Family History           1000 non-null   object
#  9   Diabetes                 1000 non-null   object
#  10  Obesity                  1000 non-null   object
#  11  Stress Level             1000 non-null   int64
#  12  Blood Sugar              1000 non-null   int64
#  13  Exercise Induced Angina  1000 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# Age                          0
# Gender                       0
# Cholesterol                  0
# Blood Pressure               0
# Heart Rate                   0
# Smoking                      0
# Alcohol Intake             340
# Exercise Hours               0
# Family History               0
# Diabetes                     0
# Obesity                      0
# Stress Level                 0
# Blood Sugar                  0
# Exercise Induced Angina      0
# Chest Pain Type              0
# Heart Disease                0
# dtype: int64

# %%
df['Alcohol Intake'].value_counts()
# Out:
# Alcohol Intake
# Heavy       346
# Moderate    314
# Name: count, dtype: int64

# %%
df['Alcohol Intake']=df['Alcohol Intake'].fillna(df['Alcohol Intake'].mode()[0])

# %%
df.isna().sum()
# Out:
# Age                        0
# Gender                     0
# Cholesterol                0
# Blood Pressure             0
# Heart Rate                 0
# Smoking                    0
# Alcohol Intake             0
# Exercise Hours             0
# Family History             0
# Diabetes                   0
# Obesity                    0
# Stress Level               0
# Blood Sugar                0
# Exercise Induced Angina    0
# Chest Pain Type            0
# Heart Disease              0
# dtype: int64

# %%
for i in df.select_dtypes(include="O").columns:
    print(f"----value_counts----{i}")
    print(df[i].value_counts())
# Out:
# ----value_counts----Gender
# Gender
# Female    503
# Male      497
# Name: count, dtype: int64
# ----value_counts----Smoking
# Smoking
# Never      338
# Current    336
# Former     326
# Name: count, dtype: int64
# ----value_counts----Alcohol Intake
# Alcohol Intake
# Heavy       686
# Moderate    314
# Name: count, dtype: int64
# ----value_counts----Family History
# Family History
# No     501
# Yes    499
# Name: count, dtype: int64
# ----value_counts----Diabetes
# Diabetes
# Yes    505
# No     495
# Name: count, dtype: int64
# ----value_counts----Obesity
# Obesity
# No     501
# Yes    499
# Name: count, dtype: int64
# ----value_counts----Exercise Induced Angina
# Exercise Induced Angina
# No     528
# Yes    472
# Name: count, dtype: int64
# ----value_counts----Chest Pain Type
# Chest Pain Type
# Non-anginal Pain    256
# Typical Angina      250
# Asymptomatic        248
# Atypical Angina     246
# Name: count, dtype: int64

# %%
# yes:1, no:0

df['Family History']= df['Family History'].map({"Yes":1,"No":0})
df['Diabetes']= df['Diabetes'].map({"Yes":1,"No":0})
df['Obesity']= df['Obesity'].map({"Yes":1,"No":0})
df['Exercise Induced Angina']= df['Exercise Induced Angina'].map({"Yes":1,"No":0})

# %%
df
# Out:
#      Age  Gender  Cholesterol  Blood Pressure  Heart Rate  Smoking  \
# 0     75  Female          228             119          66  Current
# 1     48    Male          204             165          62  Current
# 2     53    Male          234              91          67    Never
# 3     69  Female          192              90          72  Current
# 4     62  Female          172             163          93    Never
# ..   ...     ...          ...             ...         ...      ...
# 995   56  Female          269             111          86    Never
# 996   78  Female          334             145          76    Never
# 997   79    Male          151             179          81    Never
# 998   60  Female          326             151          68   Former
# 999   53    Male          226             116          82  Current
#
#     Alcohol Intake  Exercise Hours  Family History  Diabetes  Obesity  \
# 0            Heavy               1               0         0        1
# ...

# %%
#female= 1, male=0

df['Gender']=df['Gender'].map({"Female":1,"Male":0})

# %%
df
# Out:
#      Age  Gender  Cholesterol  Blood Pressure  Heart Rate  Smoking  \
# 0     75       1          228             119          66  Current
# 1     48       0          204             165          62  Current
# 2     53       0          234              91          67    Never
# 3     69       1          192              90          72  Current
# 4     62       1          172             163          93    Never
# ..   ...     ...          ...             ...         ...      ...
# 995   56       1          269             111          86    Never
# 996   78       1          334             145          76    Never
# 997   79       0          151             179          81    Never
# 998   60       1          326             151          68   Former
# 999   53       0          226             116          82  Current
#
#     Alcohol Intake  Exercise Hours  Family History  Diabetes  Obesity  \
# 0            Heavy               1               0         0        1
# ...

# %%
df['Heart Disease'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df['Heart Disease'].value_counts()
# 0: no, 1: yes
# Out:
# Heart Disease
# 0    608
# 1    392
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,3))
sns.set_style('whitegrid')
sns.countplot(x='Heart Disease', data=df, palette='hot')
plt.title('Count Plot of Heart Disease', color='black', fontsize=16, fontweight='bold')
plt.xlabel('Target (1: Yes, 0: No heart Disease)')
plt.ylabel('Count', color='black')
plt.show()


plt.show()

# %%
df.groupby("Heart Disease").mean(numeric_only=True)
# Out:
#                      Age    Gender  Cholesterol  Blood Pressure  Heart Rate  \
# Heart Disease
# 0              44.128289  0.514803   232.972039      135.134868   79.082237
# 1              64.956633  0.484694   276.255102      135.507653   79.392857
#
#                Exercise Hours  Family History  Diabetes   Obesity  \
# Heart Disease
# 0                    4.562500        0.486842  0.498355  0.506579
# 1                    4.477041        0.517857  0.515306  0.487245
#
#                Stress Level  Blood Sugar  Exercise Induced Angina
# Heart Disease
# 0                  5.629934   135.324013                 0.470395
# 1                  5.670918   134.346939                 0.474490

# %% [markdown]
# # Visualisation on Categorical data

# %%
categorical_cols = ['Gender', 'Smoking', 'Alcohol Intake',  'Diabetes', 'Obesity', 'Exercise Induced Angina', 'Chest Pain Type']
plt.figure(figsize=(15, 12))
for i, col in enumerate(categorical_cols,1):
    plt.subplot(3, 3, i)
    sns.countplot(data=df, x=col)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
df= pd.get_dummies(df, columns=['Smoking','Alcohol Intake','Chest Pain Type'],drop_first=True,dtype="int")

# %%
df
# Out:
#      Age  Gender  Cholesterol  Blood Pressure  Heart Rate  Exercise Hours  \
# 0     75       1          228             119          66               1
# 1     48       0          204             165          62               5
# 2     53       0          234              91          67               3
# 3     69       1          192              90          72               4
# 4     62       1          172             163          93               6
# ..   ...     ...          ...             ...         ...             ...
# 995   56       1          269             111          86               5
# 996   78       1          334             145          76               6
# 997   79       0          151             179          81               4
# 998   60       1          326             151          68               8
# 999   53       0          226             116          82               6
#
#      Family History  Diabetes  Obesity  Stress Level  Blood Sugar  \
# ...

# %% [markdown]
# # Separating the Features and Target

# %%
x= df.drop("Heart Disease",axis=1)
y= df['Heart Disease']

# %%
columns= x.columns

# %%
columns
# Out:
# Index(['Age', 'Gender', 'Cholesterol', 'Blood Pressure', 'Heart Rate',
#        'Exercise Hours', 'Family History', 'Diabetes', 'Obesity',
#        'Stress Level', 'Blood Sugar', 'Exercise Induced Angina',
#        'Smoking_Former', 'Smoking_Never', 'Alcohol Intake_Moderate',
#        'Chest Pain Type_Atypical Angina', 'Chest Pain Type_Non-anginal Pain',
#        'Chest Pain Type_Typical Angina'],
#       dtype='object')

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 995    1
# 996    1
# 997    0
# 998    1
# 999    1
# Name: Heart Disease, Length: 1000, dtype: int64

# %% [markdown]
# # To scale down the values

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mn= MinMaxScaler()

# %%
x= mn.fit_transform(x)

# %%
x= pd.DataFrame(x,columns= columns)

# %%
x
# Out:
#           Age  Gender  Cholesterol  Blood Pressure  Heart Rate  \
# 0    0.925926     1.0     0.391960        0.325843    0.153846
# 1    0.425926     0.0     0.271357        0.842697    0.051282
# 2    0.518519     0.0     0.422111        0.011236    0.179487
# 3    0.814815     1.0     0.211055        0.000000    0.307692
# 4    0.685185     1.0     0.110553        0.820225    0.846154
# ..        ...     ...          ...             ...         ...
# 995  0.574074     1.0     0.597990        0.235955    0.666667
# 996  0.981481     1.0     0.924623        0.617978    0.410256
# 997  1.000000     0.0     0.005025        1.000000    0.538462
# 998  0.648148     1.0     0.884422        0.685393    0.205128
# 999  0.518519     0.0     0.381910        0.292135    0.564103
#
#      Exercise Hours  Family History  Diabetes  Obesity  Stress Level  \
# 0          0.111111             0.0       0.0      1.0      0.777778
# ...

# %% [markdown]
# # Splitting the data into Training & Testing

# %%
from sklearn.model_selection import train_test_split

# %%
x_test,x_train,y_test,y_train= train_test_split(x,y,random_state=32,test_size=0.2,shuffle=True,stratify=y)

# %%
print("shape of x_test:",x_test.shape)
print("shape of x_train:",x_train.shape)
print("shape of y_test:",y_test.shape)
print("shape of y_train:",y_train.shape)
# Out:
# shape of x_test: (800, 18)
# shape of x_train: (200, 18)
# shape of y_test: (800,)
# shape of y_train: (200,)

# %% [markdown]
# # Building Model

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr= LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.85125

# %%
lr.score(x_train,y_train)
# Out:
# 0.88

# %%
lr_prob= lr.predict_proba(x_test)

# %%
lr_prob= lr_prob[:,1]

# %%
result= pd.DataFrame(lr_prob,columns=['LR_PROB'])

# %%
result
# Out:
#       LR_PROB
# 0    0.347859
# 1    0.390059
# 2    0.020656
# 3    0.037512
# 4    0.230603
# ..        ...
# 795  0.802411
# 796  0.175296
# 797  0.266165
# 798  0.906411
# 799  0.039543
#
# [800 rows x 1 columns]

# %%
pred= lr.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,precision_score,recall_score,accuracy_score,f1_score,fbeta_score,auc

# %%
from sklearn import metrics

# %%
#result= pd.DataFrame(train_score.keys(),columns=["Model_name"])
#result["Train_Evaluation_value"]= train_score.values()
#result["Test_Evaluation_Values"]= test_score.values()

# %%
#test_prob

# %%
#Accuracy: Accuracy measures the percentage of predictions that the model gets correct.
#Precision: The precision is the percentage of positive predictions that are actually positive.
#Recall: The recall is the percentage of actual positives that are predicted positive.
#F1 score: The F1 score is a weighted average of precision and recall.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

# %%
model_dic= {"Random_Forest_Classifier":RandomForestClassifier(),
           "Ada_Boost_Classifier":AdaBoostClassifier(),
           "Gradient_Boosting_Classifier":GradientBoostingClassifier(),
           "Decision_Tree_Classifier":DecisionTreeClassifier(),
           "Logistic_Regression":LogisticRegression()}

# %%
train_score={}
test_score={}
train_prob={}
test_prob={}
for name,model in model_dic.items():
    model.fit(x_train,y_train)
    train_score[name]=model.score(x_train,y_train)
    test_score[name]=model.score(x_test,y_test)
    train_t= model.predict_proba(x_train)
    test_t=model.predict_proba(x_test)
    train_prob[name]=train_t[:,1]
    test_prob[name]=test_t[:,1]

# %%
train_score
# Out:
# {'Random_Forest_Classifier': 1.0,
#  'Ada_Boost_Classifier': 1.0,
#  'Gradient_Boosting_Classifier': 1.0,
#  'Decision_Tree_Classifier': 1.0,
#  'Logistic_Regression': 0.88}

# %%
test_score
# Out:
# {'Random_Forest_Classifier': 0.99875,
#  'Ada_Boost_Classifier': 0.99625,
#  'Gradient_Boosting_Classifier': 0.99625,
#  'Decision_Tree_Classifier': 0.99625,
#  'Logistic_Regression': 0.85125}

# %%
result= pd.DataFrame(train_score.keys(),columns=["Model_name"])
result["Train_Evaluation_value"]= train_score.values()
result["Test_Evaluation_Values"]= test_score.values()

# %%
result
# Out:
#                      Model_name  Train_Evaluation_value  \
# 0      Random_Forest_Classifier                    1.00
# 1          Ada_Boost_Classifier                    1.00
# 2  Gradient_Boosting_Classifier                    1.00
# 3      Decision_Tree_Classifier                    1.00
# 4           Logistic_Regression                    0.88
#
#    Test_Evaluation_Values
# 0                 0.99875
# 1                 0.99625
# 2                 0.99625
# 3                 0.99625
# 4                 0.85125

# %%
probability_score= pd.DataFrame(train_prob.keys(),columns=["Model_Name"])
probability_score["Train_prob"]= train_prob.values()

# %%
probability_score_test= pd.DataFrame(test_prob.values())

# %%
probability_score_test=probability_score_test.T

# %%
probability_score_test=probability_score_test.rename(columns={0:"Random_Forest_Classifier",1:"Ada_Boost_Classifier",
                                      2:"Gradient_Boosting_Classifier",
                                      3:"Decision_Tree_Classifier",
                                      4:"Logistic_Regression"})

# %%
probability_score_test.columns
# Out:
# Index(['Random_Forest_Classifier', 'Ada_Boost_Classifier',
#        'Gradient_Boosting_Classifier', 'Decision_Tree_Classifier',
#        'Logistic_Regression'],
#       dtype='object')

# %%
fpr_rfr, tpr_rfr, threshold_rfr = metrics.roc_curve(y_test,probability_score_test["Random_Forest_Classifier"] )
roc_auc_rfr = metrics.auc(fpr_rfr, tpr_rfr)
fpr_Ada_Boost, tpr_Ada_Boost, threshold_Ada_Boost = metrics.roc_curve(y_test,probability_score_test["Ada_Boost_Classifier"] )
roc_auc_Ada_Boost = metrics.auc(fpr_Ada_Boost, tpr_Ada_Boost)
fpr_Gradient, tpr_Gradient, threshold_Gradient = metrics.roc_curve(y_test,probability_score_test["Gradient_Boosting_Classifier"] )
roc_auc_Gradient = metrics.auc(fpr_Gradient, tpr_Gradient)
fpr_Decision, tpr_Decision, threshold_Decision = metrics.roc_curve(y_test,probability_score_test["Decision_Tree_Classifier"] )
roc_auc_Decision = metrics.auc(fpr_Decision, tpr_Decision)
fpr_Logistic, tpr_Logistic, threshold_Logistic = metrics.roc_curve(y_test,probability_score_test["Logistic_Regression"] )
roc_auc_Logistic = metrics.auc(fpr_Logistic, tpr_Logistic)

# %%
print("Random_Forest",roc_auc_rfr)
print("Ada_Boost_Classifier",roc_auc_Ada_Boost)
print("Gradient_Boost_Classifier",roc_auc_Gradient)
print("Decision_tree_classifier",roc_auc_Decision)
print("Logistic_Classifier",roc_auc_Logistic)
# Out:
# Random_Forest 0.9999934470918194
# Ada_Boost_Classifier 0.9969135802469136
# Gradient_Boost_Classifier 0.9969135802469136
# Decision_tree_classifier 0.9969135802469136
# Logistic_Classifier 0.9363057324840766

# %%
plt.figure(figsize=(10,7))
plt.title('Receiver Operating Characteristic')
plt.plot(fpr_rfr, tpr_rfr, 'b', label = 'AUC_rfr = %0.2f' % roc_auc_rfr)
plt.plot(fpr_Ada_Boost, tpr_Ada_Boost, 'r', label = 'AUC_Ada_Boost = %0.2f' % roc_auc_Ada_Boost)
plt.plot(fpr_Gradient, tpr_Gradient, 'orange', label = 'AUC_Gradient = %0.2f' % roc_auc_Gradient)
plt.plot(fpr_Decision, tpr_Decision, 'green', label = 'AUC_Decision = %0.2f' % roc_auc_Decision)
plt.plot(fpr_Logistic, tpr_Logistic, 'purple', label = 'AUC_Logistic = %0.2f' % roc_auc_Logistic)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.feature_selection import RFE

# %%
lr= LogisticRegression()

# %%
rfe= RFE(estimator=lr,n_features_to_select=15)

# %%
rfe.fit(x_train,y_train)
# Out:
# RFE(estimator=LogisticRegression(), n_features_to_select=15)

# %%
rfe.support_
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True, False,  True,  True, False, False])

# %%
x_train= x_train[x_train.columns[rfe.support_]]

# %%
x_test= x_test[x_test.columns[rfe.support_]]

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.88

# %%
lr.score(x_test,y_test)
# Out:
# 0.85125

# %%
lr= lr.predict(x_test)

# %%
lr= pd.DataFrame(pred,columns=['Predictions'])

# %%
lr['Actual Data']= np.array(y_test)

# %%
lr
# Out:
#      Predictions  Actual Data
# 0              0            1
# 1              0            1
# 2              0            0
# 3              0            0
# 4              0            0
# ..           ...          ...
# 795            1            1
# 796            0            1
# 797            0            0
# 798            1            1
# 799            0            0
#
# [800 rows x 2 columns]

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
cn= confusion_matrix(pred,y_test)

# %%
cn
# Out:
# array([[459,  92],
#        [ 27, 222]], dtype=int64)

# %%
report= classification_report(pred,y_test)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.83      0.89       551
#            1       0.71      0.89      0.79       249
#
#     accuracy                           0.85       800
#    macro avg       0.83      0.86      0.84       800
# weighted avg       0.87      0.85      0.86       800

# %% [markdown]
# # Conclusion

# %% [markdown]
# The Logistic Regression model performed well in predicting heart disease, achieving an accuracy of 85%. The model's recall for heart disease cases (class 1) is particularly strong at 0.89, indicating that it correctly identifies 89% of the actual heart disease cases. However, the precision for predicting heart disease (0.71) suggests some false positives, which could lead to unnecessary concerns for patients without heart disease. The f1-score of 0.79 for class 1 indicates a good balance between precision and recall.

# %% [markdown]
# # Recommendations:

# %% [markdown]
# 1. Improve Precision for Heart Disease: To reduce false positives, further model tuning, such as using different algorithms (e.g., RandomForest, SVM) or applying techniques like cross-validation, might improve precision.
# 2. Feature Engineering: Investigate feature interactions or additional variables that may enhance the model’s predictive performance, especially those related to lifestyle and medical history.

# %% [markdown]
# # Summary:

# %% [markdown]
# The heart disease prediction model based on Logistic Regression demonstrates a strong ability to predict actual heart disease cases with high recall, though there is room for improvement in precision. The model achieves a solid overall performance with an accuracy of 85% and an f1-score of 0.84, making it a useful tool for preliminary heart disease diagnosis.
